# %% [markdown]
# <a href="https://colab.research.google.com/github/medellins/medellins.github.io/blob/master/Jesus_Garcia_Medellin_Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - Proyecto integrador: Sobreviviendo
# del Titanic

# %% [markdown]
# - 1.- CARGAR DATOS
# *Análisis Exploratorio

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
passengers= pd.read_csv('/content/drive/MyDrive/TITANIC/train_titanic.csv')
passengers1=pd.read_csv('/content/drive/MyDrive/TITANIC/test_titanic.csv')

# %%
len(passengers)
# Out:
# 891

# %%
passengers.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
passengers1.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
passengers.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
passengers.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
passengers.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
passengers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
passengers.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
passengers.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# -LIMPIAR DATOS
#
# 2.- Actualizar a valor numérico la variable Sex

# %%
#otro codigo para cambiar valores de sexo 1,0
#passenger['sex'].replace['female','male'],[0,1], inplace=True
pd.get_dummies(passengers['Sex'])#extraemos los valores de la variable Sex
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
gender=pd.get_dummies(passengers['Sex'],drop_first=True)#creamos una nueva columna gender y eliminamos de la columna Sex la variable female

# %%
passengers['sex']=gender#cambiamos el nombre de la columna gender por sex

# %%
passengers.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  sex
# 0      0         A/5 21171   7.2500   NaN        S    1
# 1      0          PC 17599  71.2833   C85        C    0
# 2      0  STON/O2. 3101282   7.9250   NaN        S    0
# 3      0            113803  53.1000  C123        S    0
# ...

# %%
passengers.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'sex'],
#       dtype='object')

# %%
# Eliminamos todas las columnas que no necesitaremos
passengers.drop(['PassengerId','SibSp','Parch', 'Ticket', 'Fare','Cabin', 'Embarked','Sex'],axis=1, inplace=True)

# %%
passengers.drop(['Name'],axis=1, inplace=True)

# %%
passengers.head(10)
# Out:
#    Survived  Pclass   Age  sex
# 0         0       3  22.0    1
# 1         1       1  38.0    0
# 2         1       3  26.0    0
# 3         1       1  35.0    0
# 4         0       3  35.0    1
# 5         0       3   NaN    1
# 6         0       1  54.0    1
# 7         0       3   2.0    1
# 8         1       3  27.0    0
# 9         1       2  14.0    0

# %% [markdown]
# - 3.- Rellenamos los valores vacíos de la variable Age con su Media

# %%
passengers['Age'].values

# %%
passengers.isnull().sum()

# %%
#RELLENAMOS VALORES DE  LA VARIABLE Age POR SU MEDIA QUE ES 30
passengers.describe()

# %%
passengers['Age']= passengers['Age'].replace(np.nan, 30)
passengers.head(22)

# %%
passengers.isnull().sum() #OBSERVAMOS QUE YA NO TENEMOS VALORES NAN EN LA VARIABLE Age

# %% [markdown]
# - 4.- Creamos la columna FirstClass

# %%
 #utilicemos la columna Pclass, o la clase de pasajeros, como otra característica. Cree una nueva
#columna llamada FirstClass que almacene 1 para todos los pasajeros en
#primera clase y 0 para todos los demás pasajeros.
passengers['FirstClass']= np.where(passengers['Pclass']==1,1,0)
passengers.head(10)
# Out:
#    Survived  Pclass   Age  sex  FirstClass
# 0         0       3  22.0    1           0
# 1         1       1  38.0    0           1
# 2         1       3  26.0    0           0
# 3         1       1  35.0    0           1
# 4         0       3  35.0    1           0
# 5         0       3   NaN    1           0
# 6         0       1  54.0    1           1
# 7         0       3   2.0    1           0
# 8         1       3  27.0    0           0
# 9         1       2  14.0    0           0

# %% [markdown]
# - 5.- Creamos la columna SecondClass

# %%
#Cree una nueva columna llamada SecondClass que almacene 1 para todos
#los pasajeros en segunda clase y 0 para todos los demás pasajeros.

passengers['SecondClass']= np.where(passengers['Pclass']==2,1,0)
passengers.head(10)
# Out:
#    Survived  Pclass   Age  sex  FirstClass  SecondClass
# 0         0       3  22.0    1           0            0
# 1         1       1  38.0    0           1            0
# 2         1       3  26.0    0           0            0
# 3         1       1  35.0    0           1            0
# 4         0       3  35.0    1           0            0
# 5         0       3   NaN    1           0            0
# 6         0       1  54.0    1           1            0
# 7         0       3   2.0    1           0            0
# 8         1       3  27.0    0           0            0
# 9         1       2  14.0    0           0            1

# %% [markdown]
# - 6.- Creamos las variables features y survival

# %%
features=passengers[['Age','sex','FirstClass','SecondClass']]
survival=passengers['Survived']

# %%
features
# Out:
#       Age  sex  FirstClass  SecondClass
# 0    22.0    1           0            0
# 1    38.0    0           1            0
# 2    26.0    0           0            0
# 3    35.0    0           1            0
# 4    35.0    1           0            0
# ..    ...  ...         ...          ...
# 886  27.0    1           0            1
# 887  19.0    0           1            0
# 888  30.0    0           0            0
# 889  26.0    1           1            0
# 890  32.0    1           0            0
#
# [891 rows x 4 columns]

# %% [markdown]
# - 7.- Dividimos los datos con el método train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
features_train, features_test, survival_train, survival_test= train_test_split(features,survival, test_size=0.33, random_state=101)

# %% [markdown]
# - 8 y 9 Utilizamos la regularización y creamos un modelo de Regresión Logística

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
lr=LogisticRegression()

# %%
lr.fit(features_train, survival_train)
# Out:
# LogisticRegression()

# %%
#PRECISION ALGORITMO REGRESION LOGISTICA
predict=lr.predict(features_test)
print('Precisión de la Regresión Logística: ')
print(lr.score(features_train,survival_train))
# Out:
# Precisión de la Regresión Logística:
# 0.7969798657718121

# %% [markdown]
# - Adicionalmente se aplicaron algoritmos de Soporte de Vectores y Vecinos más Cercanos para una comparación más profunda

# %%
#PRECISION ALGORITMO SOPORTE DE VECTORES
svc=SVC()
svc.fit(features_train,survival_train)
Y_pred=svc.predict(features_test)
print('Precisión de Soporte de Vectores: ')
print(svc.score(features_train,survival_train))
# Out:
# Precisión de Soporte de Vectores:
# 0.6375838926174496

# %%
#PRECISION ALGORITMO VECINOS MAS CERCANOS
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(features_train,survival_train)
print('Precisión de Vecinos más cercanos: ')
print(knn.score(features_train,survival_train))
# Out:
# Precisión de Vecinos más cercanos:
# 0.8489932885906041

# %%
#ANALISIS DE LOS ALGORITMOS UTILIZADOS
print('Precisión de la Regresión Logística: ')
print(lr.score(features_train,survival_train))
print('')
print('Precisión de Soporte de Vectores: ')
print(svc.score(features_train,survival_train))
print('')
print('Precisión de Vecinos más cercanos: ')
print(knn.score(features_train,survival_train))
# Out:
# Precisión de la Regresión Logística:
# 0.7969798657718121
#
# Precisión de Soporte de Vectores:
# 0.6375838926174496
#
# Precisión de Vecinos más cercanos:
# 0.8489932885906041

# %% [markdown]
# - Por lo que podemos concluir que el mejor algoritmo es el de Vecinos más Cercanos con 84% de confianza

# %% [markdown]
# - 10, 11 y 12 Se obtiene el puntaje de entrenamiento, la puntuación de prueba y los coeficientes de característica determoinados por el modelo.
#
# - Se crea una matriz de confusión para visualizar de mejor manera los datos.

# %%
from sklearn.metrics import confusion_matrix

# %%
pd.DataFrame(confusion_matrix(survival_test,predict),columns=['Predicted Survived NO', 'Predicted Survived YES'],index=['Actual survived NO','Actual survived YES'])
# Out:
#                      Predicted Survived NO  Predicted Survived YES
# Actual survived NO                     149                      20
# Actual survived YES                     41                      85

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(survival_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83       169
#            1       0.81      0.67      0.74       126
#
#     accuracy                           0.79       295
#    macro avg       0.80      0.78      0.78       295
# weighted avg       0.80      0.79      0.79       295

# %% [markdown]
# - En la siguiente sección se realizó la limpieza de datos del Data Frame de Prueba que se utilizará posteriormente para realizar las Predicciones.

# %%
passengers1['Sex'].replace(['female','male'],[0,1], inplace=True)
passengers1.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
passengers1['Embarked'].replace(['Q','S','C'],[0,1,2], inplace=True)

# %%
passengers1.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare Cabin  Embarked
# 0  34.5      0      0   330911   7.8292   NaN         0
# 1  47.0      1      0   363272   7.0000   NaN         1
# 2  62.0      0      0   240276   9.6875   NaN         0
# 3  27.0      0      0   315154   8.6625   NaN         1
# 4  22.0      1      1  3101298  12.2875   NaN         1

# %%
passengers1.drop(['Cabin'], axis=1, inplace=True)
passengers1.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare  Embarked
# 0  34.5      0      0   330911   7.8292         0
# 1  47.0      1      0   363272   7.0000         1
# 2  62.0      0      0   240276   9.6875         0
# 3  27.0      0      0   315154   8.6625         1
# 4  22.0      1      1  3101298  12.2875         1

# %%
passengers1.drop(['SibSp'], axis=1, inplace=True)
passengers1.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  Parch   Ticket     Fare  Embarked
# 0  34.5      0   330911   7.8292         0
# 1  47.0      0   363272   7.0000         1
# 2  62.0      0   240276   9.6875         0
# 3  27.0      0   315154   8.6625         1
# 4  22.0      1  3101298  12.2875         1

# %%
passengers1.drop(['Name','Parch','Ticket','Fare'], axis=1, inplace=True)

# %%
passengers1.head()
# Out:
#    PassengerId  Pclass  Sex   Age  Embarked
# 0          892       3    1  34.5         0
# 1          893       3    0  47.0         1
# 2          894       2    1  62.0         0
# 3          895       3    1  27.0         1
# 4          896       3    0  22.0         1

# %%
passengers1.dropna(axis=0, how='any', inplace=True)

# %% [markdown]
# - 13 a 16
# * Se realizaron diferentes predicciones tomando en cuenta las variables PassengerId del dataset de Prueba.
# * Asimismo se utilizaron los algoritmos de Regresión Logística, Soporte de Vectores y Vecinos más Cercanos para una predicción más profunda.

# %%
#PREDICCIONES
ids=passengers1['PassengerId']

# %%
#PREDICCION CON REGRESION LOGISTICA
lr=lr.predict(passengers1.drop('PassengerId', axis=1))
out_logreg=pd.DataFrame({'PassengerId': ids, 'Survived': lr })
print('Predicción Regresión Logística: ')
print(out_logreg.head())
# Out:
# Predicción Regresión Logística:
#    PassengerId  Survived
# 0          892         1
# 1          893         1
# 2          894         1
# 3          895         1
# 4          896         1
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Embarked
# - Pclass
# - Sex
# Feature names seen at fit time, yet now missing:
# - FirstClass
# - SecondClass
# - sex
#
#   warnings.warn(message, FutureWarning)

# %%
#PREDICCION CON SOPORTE DE VECTORES
pred_svc=svc.predict(passengers1.drop('PassengerId', axis=1))
out_svc=pd.DataFrame({'PassengerId': ids, 'Survived': pred_svc })
print('Predicción Soporte de Vectores: ')
print(out_svc.head())
# Out:
# Predicción Soporte de Vectores:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         1
# 4          896         1
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Embarked
# - Pclass
# - Sex
# Feature names seen at fit time, yet now missing:
# - FirstClass
# - SecondClass
# - sex
#
#   warnings.warn(message, FutureWarning)

# %%
#PREDICCION CON VECINOS MAS CERCANOS
pred_knn=knn.predict(passengers1.drop('PassengerId', axis=1))
out_knn=pd.DataFrame({'PassengerId': ids, 'Survived': pred_knn })
print('Predicción Vecinos más cercanos: ')
print(out_knn.head())
# Out:
# Predicción Vecinos más cercanos:
#    PassengerId  Survived
# 0          892         1
# 1          893         1
# 2          894         1
# 3          895         1
# 4          896         1
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Embarked
# - Pclass
# - Sex
# Feature names seen at fit time, yet now missing:
# - FirstClass
# - SecondClass
# - sex
#
#   warnings.warn(message, FutureWarning)

# %%
print('Predicción Regresión Logística: ')
print(out_logreg.head(10))
print('')
print('Predicción Soporte de Vectores: ')
print(out_svc.head(10))
print('')
print('Predicción Vecinos más cercanos: ')
print(out_knn.head(10))
# Out:
# Predicción Regresión Logística:
#    PassengerId  Survived
# 0          892         1
# 1          893         1
# 2          894         1
# 3          895         1
# 4          896         1
# 5          897         1
# 6          898         1
# 7          899         1
# 8          900         1
# 9          901         1
#
# Predicción Soporte de Vectores:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         1
# 4          896         1
# 5          897         1
# 6          898         1
# 7          899         1
# 8          900         1
# 9          901         1
#
# Predicción Vecinos más cercanos:
#    PassengerId  Survived
# 0          892         1
# 1          893         1
# 2          894         1
# 3          895         1
# 4          896         1
# 5          897         1
# 6          898         0
# 7          899         1
# 8          900         1
# 9          901         1

# %% [markdown]
# - Haciendo un análisis de los algoritmos utilizados en las predicciones, tenemos que en la Regresión Logística los 10 primeros pasajeros sobrevivirán y en el de Vecinos más cercanos los primeros 9 pasajeros sobrevivirán y uno no lo hará.
# Y en el algoritmo de Soporte de Vectores, los primeros 3 pasajeros No sobrevivirán y los siguientes 7 sí lo harán, por lo que este modelo está más cercano a la realidad, en base a los datos proporcionados.
